# %% [markdown]
# W1A1
# a = 7
# • Gán giá trị 7 cho biến a.
# Tức là sau dòng này, a = 7.
#
# b = 5
# • Gán giá trị 5 cho biến b.
# Sau dòng này, b = 5.
#
# c = a - b
# • Thực hiện phép trừ giữa a và b, tức là 7 - 5 = 2.
# Kết quả 2 được gán cho biến c.
# Sau dòng này, c = 2.
#
# print(c)
# • In giá trị của biến c ra màn hình.
# Do c = 2, nên chương trình sẽ in ra kết quả:

# %%
a=7
b=5
c=a-b
print(c)
# Out:
# 2

# %% [markdown]
# W1A2
# city = "Hà Nội"
# • Dòng này khai báo biến city và gán giá trị chuỗi "Hà Nội" cho nó.
# → Sau khi thực hiện, biến city lưu trữ chuỗi "Hà Nội".
#
# year = 2025
# • Dòng này khai báo biến year và gán giá trị số nguyên 2025 cho nó.
# → Sau khi thực hiện, biến year có giá trị 2025.
#
# print("Thành phố: ", city, "- Năm:", year)
# • Câu lệnh print() dùng để in dữ liệu ra màn hình.
# • Nó in lần lượt các phần tử được phân tách bằng dấu phẩy , (Python tự động thêm một dấu cách giữa các phần tử khi in).
#
# 🔹 Giải thích vì sao ra kết quả đó:
#
#     • Python nối (ghép) các phần trong print() lại với nhau bằng khoảng trắng mặc định.
#     • Các giá trị chuỗi và số (str và int) có thể in cùng lúc nhờ print() tự động chuyển đổi kiểu dữ liệu về dạng chuỗi khi in.

# %%
city = "Hà Nội"
year = 2025
print("Thành phố: ", city, "- Năm:", year)
# Out:
# Thành phố:  Hà Nội - Năm: 2025

# %% [markdown]
# W1A3
# n = 4
# • Khai báo biến n và gán giá trị nguyên 4. n đại diện cho số cuối cùng trong dãy số sẽ cộng (từ 1 đến n).
#
# t = 0
# • Khai báo biến t (viết tắt của "tổng") và khởi tạo bằng 0. Biến này dùng để lưu kết quả tổng dần.
#
# for i in range(1, n+1):
# • Vòng lặp for lặp qua các giá trị i trong range(1, n+1).
# • range(1, n+1) tạo dãy số bắt đầu từ 1 đến n bao gồm n (vì range ở Python cận phải là không bao gồm, nên ta dùng n+1 để lấy n).
# • Với n = 4, i lần lượt nhận các giá trị: 1, 2, 3, 4.
#
# t += i
# • Đây là viết tắt của t = t + i.
# • Mỗi lần lặp, giá trị hiện tại của i được cộng vào biến t.
# • Quá trình cập nhật khi n=4:
# • ban đầu t = 0:
# → i = 1 → t = 0 + 1 = 1
# → i = 2 → t = 1 + 2 = 3
# → i = 3 → t = 3 + 3 = 6
# → i = 4 → t = 6 + 4 = 10
# print(t)
# •In giá trị hiện tại của t ra màn hình. Sau khi vòng lặp kết thúc, t chứa tổng các số từ 1 đến n.

# %%
n=4 
t=0 
for i in range(1,n+1): 
    t += i 
    print(t)
# Out:
# 1
# 3
# 6
# 10

# %% [markdown]
# W1A4
# numbers = [1, 2, 3, 4]
# • Khai báo một danh sách (list) tên numbers chứa bốn số nguyên: 1, 2, 3, 4.
#
# for x in numbers:
# • Vòng lặp for lấy lần lượt từng phần tử trong danh sách numbers và gán cho biến x.
# Lần lượt x sẽ là 1, rồi 2, rồi 3, rồi 4.
#
# if x % 2 == 0:
# • Dòng này kiểm tra điều kiện chia hết cho 2 hay không bằng toán tử x % 2 (phần dư khi chia x cho 2).
# Nếu phần dư bằng 0 (== 0) nghĩa là x là số chẵn.
#
# print(x, "là số chẵn")
# • Nếu điều kiện đúng (x chẵn), in ra dòng "x là số chẵn". print khi dùng nhiều tham số cách nhau dấu phẩy sẽ in có một khoảng trắng giữa các mục.
#
# else:
# print(x, "là số lẻ")
# • Nếu điều kiện if sai (tức x % 2 != 0), thực hiện nhánh else và in "x là số lẻ".
#
# 🔢 Vì sao kết quả như vậy
# • Với x = 1: 1 % 2 = 1 (không bằng 0) → in 1 là số lẻ.
# • Với x = 2: 2 % 2 = 0 → in 2 là số chẵn.
# • Tương tự cho 3 và 4.

# %%
numbers= [1, 2, 3, 4] 
for x in numbers: 
    if x % 2 ==0: 
        print(x, "là số chẵn") 
    else: 
        print(x, "là số lẻ")
# Out:
# 1 là số lẻ
# 2 là số chẵn
# 3 là số lẻ
# 4 là số chẵn

# %% [markdown]
# W1A5
# animals = ["cat", "dog", "cat", "bird"]
#     • Khai báo một danh sách animals chứa 4 phần tử chuỗi: "cat", "dog", "cat", "bird".
#
# count = 0
#     • Khởi tạo biến count (đếm) bằng 0. Biến này sẽ dùng để đếm số phần tử trong danh sách.
#
# for a in animals:
#     • Duyệt từng phần tử trong danh sách animals. Mỗi lần lặp, biến a nhận giá trị của phần tử hiện tại (ví dụ "cat", rồi "dog", ...).
#
# count += 1
#     • Viết tắt của count = count + 1. Mỗi lần lặp (tức mỗi phần tử) tăng biến count lên 1.
#
# print("Số phần tử trong danh sách là:", count)
#     • In thông báo kèm giá trị hiện tại của count. print với nhiều tham số phân tách bằng dấu phẩy sẽ tự thêm một khoảng trắng giữa các phần.

# %%
animals = ["cat", "dog", "cat", "bird"]
count = 0
for a in animals:
    count += 1
print("Số phần tử trong danh sách là:", count)
# Out:
# Số phần tử trong danh sách là: 4

# %% [markdown]
# W1A6
# 🔹 Nhận xét đầu tiên
#         • Đây không phải là một chương trình Python hoàn chỉnh, mà là phần hiển thị (giao diện văn bản) — tức các dòng được in ra cho người dùng xem.
#         • Thực tế, đây có thể là phần menu chính của một chương trình có tên “AI Prediction System” (Hệ thống dự đoán bằng AI).
#
# ===AI Prediction System===
# 👉 Là dòng tiêu đề, in ra để giới thiệu chương trình.
#
# 1) Sentiment analysis
# 👉 Hiển thị tùy chọn 1: Phân tích cảm xúc.
# Trong một chương trình thật, nếu người dùng nhập 1, chương trình sẽ gọi hàm phân tích cảm xúc (ví dụ: nhận diện câu nói là “tích cực”, “tiêu cực”, hay “trung lập”).
#
# 2) Weather forecast
# 👉 Hiển thị tùy chọn 2: Dự báo thời tiết.
# Khi chọn tùy chọn này, chương trình có thể truy cập dữ liệu thời tiết (hoặc mô phỏng AI dự đoán thời tiết).
#
# 3) Exit
# 👉 Hiển thị tùy chọn 3: Thoát chương trình.
# Nếu người dùng chọn 3, chương trình sẽ dừng lại (thường bằng break hoặc exit()).
#
# Please choose an option:
# 👉 Là dòng yêu cầu người dùng nhập lựa chọn.
#
# 🔹 Vì sao có “kết quả” này?
#     • Chương trình (hoặc phần khởi động) đang in ra các dòng hướng dẫn cho người dùng — không phải là kết quả tính toán, mà là menu hiển thị.
#     • “Kết quả” mà bạn thấy chính là các chuỗi được in ra bằng hàm print() trong Python.

# %%
print("===AI Prediction System===")
print("1) Sentiment analysis")
print("2) Weather forecast")
print("3) Exit")
choice = input("Please choose an option: ")
# Out:
# ===AI Prediction System===
# 1) Sentiment analysis
# 2) Weather forecast
# 3) Exit

# %% [markdown]
# W1A7
# Các lỗi chính:
#     1.input() trả về chuỗi (string). Phải chuyển sang số nguyên (int) trước khi dùng phép toán %.
#     2.Toán tử so sánh bằng trong Python là ==, bạn dùng = (dấu = là gán, không hợp lệ trong if).
#     3.Thiếu dấu hai chấm : sau điều kiện if (cú pháp bắt buộc).
#     4.Thiếu thụt lề cho thân if/else (Python bắt buộc).
#     5.Thiếu dấu : sau else cũng là lỗi cú pháp.
#     6.Thiếu khoảng trắng/định dạng làm cho code khó đọc (không bắt buộc nhưng nên chuẩn).

# %%
num = int(input("Nhập số: "))
if num % 2 == 0:
    print("Số chẵn")
else:
    print("Số lẻ")
# Out:
# Số lẻ

# %% [markdown]
# W1A8
# 🔹 Giải thích từng dòng:
# 1️⃣ for i in range(3):
#     • Đây là vòng lặp for chạy với các giá trị i lần lượt từ 0 đến 2.
#     (range(3) tạo ra dãy [0, 1, 2] gồm 3 phần tử.)
# 2️⃣ print("AI đang học lần", i+1)
#     • Mỗi lần lặp, câu lệnh này được thực thi một lần.
#     • i+1 được dùng để hiển thị số lần học bắt đầu từ 1 (thay vì 0).
#     • Do đó, nó sẽ in ra 3 dòng
# 3️⃣ print("Huấn luyện xong!")
#     • Lệnh này nằm ngoài vòng lặp, nên chỉ được thực thi một lần duy nhất, sau khi vòng lặp kết thúc.

# %%
for i in range(3):
    print("AI đang học lần", i+1)
print("Huấn luyện xong!")
# Out:
# AI đang học lần 1
# AI đang học lần 2
# AI đang học lần 3
# Huấn luyện xong!

# %% [markdown]
# W1A9
# 🔹 Giải thích từng dòng:
# 1️⃣ for x in ["cat", "dog", "fish"]:
#     • Đây là vòng lặp for.
#     • Danh sách ["cat", "dog", "fish"] gồm 3 phần tử chuỗi: "cat", "dog", và "fish".
#     • Biến x sẽ lần lượt nhận giá trị của từng phần tử trong danh sách này, theo thứ tự.
# 2️⃣ print("Dự đoán con vật:", x)
#     • Trong mỗi lần lặp, Python in ra dòng chữ "Dự đoán con vật:" rồi thêm giá trị hiện tại của x.
#
# 🔹 Số dòng được in:
# 👉 3 dòng — vì danh sách có 3 phần tử nên vòng lặp chạy 3 lần.

# %%
for x in ["cat", "dog", "fish"]:
    print("Dự đoán con vật:", x)
# Out:
# Dự đoán con vật: cat
# Dự đoán con vật: dog
# Dự đoán con vật: fish

# %% [markdown]
# W1A10
# 🔍 Phân tích lỗi từng dòng:
#
# 1️⃣ print("===AI Prediction System") ✅
# → Dòng này đúng cú pháp, không cần sửa.
#
# 2️⃣ print("1) Sentiment analysis" ❌
# → Thiếu dấu ngoặc đóng ) ở cuối dòng.
#
# 3️⃣ print("2) Weather forecast")) ❌
# → Dư một dấu ngoặc ).
#
# 4️⃣ print('3) Exit' ❌
# → Thiếu dấu ngoặc đóng ) ở cuối.
#
# 5️⃣ print("Please choose an option:") ✅
# → Dòng này đúng cú pháp.

# %%
# Simple menu
print("===AI Prediction System===")
print("1) Sentiment analysis")
print("2) Weather forecast")
print("3) Exit")
print("Please choose an option:")
# Out:
# ===AI Prediction System===
# 1) Sentiment analysis
# 2) Weather forecast
# 3) Exit
# Please choose an option:
